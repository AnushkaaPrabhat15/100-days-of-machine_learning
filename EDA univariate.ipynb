# %%
import pandas as pd
import seaborn as sns

# %%
df= pd.read_csv('/Users/anushkaaprabhat/Desktop/Datasets/Salary_dataset.csv' ,)

# %%
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.drop(['Unnamed: 0'], axis=1)
# Out:
#     YearsExperience    Salary
# 0               1.2   39344.0
# 1               1.4   46206.0
# 2               1.6   37732.0
# 3               2.1   43526.0
# 4               2.3   39892.0
# 5               3.0   56643.0
# 6               3.1   60151.0
# 7               3.3   54446.0
# 8               3.3   64446.0
# 9               3.8   57190.0
# 10              4.0   63219.0
# 11              4.1   55795.0
# 12              4.1   56958.0
# 13              4.2   57082.0
# 14              4.6   61112.0
# 15              5.0   67939.0
# 16              5.2   66030.0
# 17              5.4   83089.0
# 18              6.0   81364.0
# 19              6.1   93941.0
# 20              6.9   91739.0
# 21              7.2   98274.0
# 22              8.0  101303.0
# 23              8.3  113813.0
# 24              8.8  109432.0
# 25              9.1  105583.0
# 26              9.6  116970.0
# 27              9.7  112636.0
# 28             10.4  122392.0
# 29             10.6  121873.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       30 non-null     int64
#  1   YearsExperience  30 non-null     float64
#  2   Salary           30 non-null     float64
# dtypes: float64(2), int64(1)
# memory usage: 848.0 bytes

# %%
df.head(5)
# Out:
#    YearsExperience   Salary
# 0              1.2  39344.0
# 1              1.4  46206.0
# 2              1.6  37732.0
# 3              2.1  43526.0
# 4              2.3  39892.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 608.0 bytes

# %%
import matplotlib.pyplot as plt

# %%
sns.countplot(df['Salary'])
# Out:
# <Axes: ylabel='count'>

# %%
df['Salary'].value_counts().plot(kind='bar')
# Out:
# <Axes: >

# %%
df['Salary'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='Salary'>

# %%
sns.countplot(df, x="Salary",hue="YearsExperience")
# Out:
# <Axes: xlabel='Salary', ylabel='count'>

# %%
plt.hist(df['Salary'],bins=5)
# Out:
# (array([ 6., 11.,  2.,  4.,  7.]),
#  array([ 37732.,  54664.,  71596.,  88528., 105460., 122392.]),
#  <BarContainer object of 5 artists>)

# %%
sns.distplot(df['Salary'])
# Out:
# /var/folders/rc/4f1fxxws5jqdl20r_nwrdh3h0000gn/T/ipykernel_3907/3249851952.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Salary'])
# <Axes: xlabel='Salary', ylabel='Density'>

# %%
sns.boxplot(df['Salary'])
# Out:
# <Axes: >

# %%
#Here we have noticed clearly that this is a NUMERICAL DATA 
#and we have performed EDA using univariate analysis..
#THANKYOUUUUU
